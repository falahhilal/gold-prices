# %%
import pandas as pd
import numpy as np

df = pd.read_csv("final_dataset.csv")
df["Date"] = pd.to_datetime(df["Date"])

# %%
#drop source col
df.drop(columns=['source'], inplace=True)

# %%
#drop rows with no date
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')
df.dropna(subset=['Date'], inplace=True)

# %%
#interpolate missing prices and volume
cols = ['Close','High','Low','Open','Volume']
daily= df.groupby('Date')[cols].mean().reset_index()
daily['Date'] = pd.to_datetime(daily['Date'])
daily.set_index('Date', inplace=True)
daily[cols] = daily[cols].interpolate(method='time')
for col in cols:
    df[col] = df['Date'].map(daily[col])

# %%
#missing sentiments
missing_headlines = df['title'].isna()
df.loc[missing_headlines, ['negative','positive']] = 0
df.loc[missing_headlines, ['neutral']] = 1

# %%
#forwrad fill for interest rate and inflation
df[['interest_rate', 'inflation']] = df[['interest_rate', 'inflation']].fillna(method='ffill')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14784\1984539751.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['interest_rate', 'inflation']] = df[['interest_rate', 'inflation']].fillna(method='ffill')

# %%
#interpolate (time based) for usd index
usd_index_daily = df.groupby('Date')['usd_index'].mean() 
usd_index_daily = usd_index_daily.interpolate(method='time')
df['usd_index'] = df['Date'].map(usd_index_daily)

# %%
#handle missing headlines
df['title'] = df['title'].fillna('no headline')

# %%
#renaming
df.rename(columns={'Date': 'date'}, inplace=True)
df.rename(columns={'Close': 'close'}, inplace=True)
df.rename(columns={'High': 'high'}, inplace=True)
df.rename(columns={'Low': 'low'}, inplace=True)
df.rename(columns={'Open': 'open'}, inplace=True)
df.rename(columns={'Volume': 'volume'}, inplace=True)
df.rename(columns={'title': 'headline'}, inplace=True)

# %%
#cleaned csv
df.to_csv('cleaned_dataset.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23693 entries, 0 to 23692
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              23693 non-null  datetime64[ns]
#  1   close             23693 non-null  float64
#  2   high              23693 non-null  float64
#  3   low               23693 non-null  float64
#  4   open              23693 non-null  float64
#  5   volume            23693 non-null  float64
#  6   headline          23693 non-null  object
#  7   negative          23693 non-null  float64
#  8   neutral           23693 non-null  float64
#  9   positive          23693 non-null  float64
#  10  interest_rate     23693 non-null  float64
#  11  inflation         23693 non-null  float64
#  12  usd_index         23693 non-null  float64
#  13  season            23693 non-null  object
#  14  year              23693 non-null  int64
#  15  month             23693 non-null  int64
#  16  day               23693 non-null  int64
#  17  day_of_week       23693 non-null  int64
#  18  week_of_year      23693 non-null  int64
#  19  quarter           23693 non-null  int64
#  20  is_weekend        23693 non-null  int64
#  21  days_since_start  23693 non-null  int64
#  22  month_sin         23693 non-null  float64
#  23  month_cos         23693 non-null  float64
#  24  dayofweek_sin     23693 non-null  float64
#  25  dayofweek_cos     23693 non-null  float64
# dtypes: datetime64[ns](1), float64(15), int64(8), object(2)
# memory usage: 4.9+ MB

# %%
#one hot encoding season
df = pd.read_csv('cleaned_dataset.csv')

season_dummies = pd.get_dummies(df['season'], prefix='season')
df = pd.concat([df, season_dummies], axis=1)
df.drop(columns=['season'], inplace=True)
df.to_csv('cleaned_dataset.csv', index=False)

# %%
#lag and rolling feature
import pandas as pd
df = pd.read_csv("cleaned_dataset.csv")

df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)
daily_close = df.groupby('date')['close'].mean().reset_index()

#Lag features
lags = [1, 3, 7, 14, 30]
for lag in lags:
    daily_close[f'Close_lag{lag}'] = daily_close['close'].shift(lag)

#Rolling features
windows = [7, 30]
for window in windows:
    daily_close[f'Close_roll_mean_{window}'] = daily_close['close'].shift(1).rolling(window).mean()

lag_roll_cols = [c for c in daily_close.columns if 'lag' in c or 'roll' in c]
df = df.merge(daily_close[['date'] + lag_roll_cols], on='date', how='left')

#removing first 30 dates coz of NaN
unique_dates = sorted(df['date'].unique())
first_30_dates = unique_dates[:30]
df = df[~df['date'].isin(first_30_dates)]

# %%
#unscaled dataset
df.to_csv("dataset.csv", index=False)

# %%
print(df.dtypes)
# Out:
# date                  datetime64[ns]
# close                        float64
# high                         float64
# low                          float64
# open                         float64
# volume                       float64
# headline                      object
# negative                     float64
# neutral                      float64
# positive                     float64
# interest_rate                float64
# inflation                    float64
# usd_index                    float64
# year                           int64
# month                          int64
# day                            int64
# day_of_week                    int64
# week_of_year                   int64
# quarter                        int64
# is_weekend                     int64
# days_since_start               int64
# month_sin                    float64
# month_cos                    float64
# dayofweek_sin                float64
# dayofweek_cos                float64
# season_Autumn                   bool
# season_Spring                   bool
# season_Summer                   bool
# season_Winter                   bool
# Close_lag1                   float64
# Close_lag3                   float64
# Close_lag7                   float64
# Close_lag14                  float64
# Close_lag30                  float64
# Close_roll_mean_7            float64
# Close_roll_mean_30           float64
# dtype: object

# %%
#EDA
import matplotlib.pyplot as plt
import seaborn as sns
import math

sns.set(style="whitegrid")
# %matplotlib inline
df = pd.read_csv("dataset.csv")  # scaled dataset for EDA
df['date'] = pd.to_datetime(df['date'])
# First rows
print(df.head())
# Info about columns
print(df.info())
# Check for any missing values
print(df.isna().sum())
# Summary statistics
print(df.describe())

plt.figure(figsize=(14,5))
plt.plot(df['date'], df['close'], label='Gold Price')
plt.title("Gold Price over Time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# Histogram
plt.figure(figsize=(8,5))
sns.histplot(df['close'], bins=50, kde=True)
plt.title("Distribution of Gold Prices")
plt.show()

# Correlation matrix
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr = numeric_df.corr()

plt.figure(figsize=(16,12))
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title("Correlation Matrix")
plt.show()

# Histograms of numeric features
numeric_cols = numeric_df.columns.tolist()
numeric_cols.remove('close')  # skip target

num_cols = len(numeric_cols)
cols = 5  
rows = math.ceil(num_cols / cols)

plt.figure(figsize=(cols*4, rows*3))
for i, col in enumerate(numeric_cols):
    plt.subplot(rows, cols, i+1)
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(col)
plt.tight_layout()
plt.show()


#Boxplots for day, month, quarter
plt.figure(figsize=(8,5))
sns.boxplot(x='day_of_week', y='close', data=df)
plt.title("Gold Price by Day of Week")
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(x='month', y='close', data=df)
plt.title("Gold Price by Month")
plt.show()

plt.figure(figsize=(6,5))
sns.boxplot(x='quarter', y='close', data=df)
plt.title("Gold Price by Quarter")
plt.show()

#Sentiment plots
sent_cols = ['negative', 'neutral', 'positive']

# Sentiment over time
plt.figure(figsize=(12,5))
for col in sent_cols:
    sns.lineplot(x=df['date'], y=df[col], label=col)
plt.title("Sentiment Scores Over Time")
plt.show()

# Scatter sentiment vs Close
plt.figure(figsize=(12,4))
for i, col in enumerate(sent_cols):
    plt.subplot(1,3,i+1)
    sns.scatterplot(x=df[col], y=df['close'])
    plt.title(f"{col} vs Close")
plt.tight_layout()
plt.show()

#Correlation-based feature importance
feature_corr = numeric_df.corr()['close'].drop('close').sort_values(ascending=False)
plt.figure(figsize=(12,6))
sns.barplot(x=feature_corr.values, y=feature_corr.index)
plt.title("Feature Correlation with Gold Price")
plt.show()
# Out:
#         date        close         high          low         open  volume  \
# 0 2019-04-12  1290.599976  1293.400024  1289.199951  1293.400024   607.0
# 1 2019-04-12  1290.599976  1293.400024  1289.199951  1293.400024   607.0
# 2 2019-04-12  1290.599976  1293.400024  1289.199951  1293.400024   607.0
# 3 2019-04-12  1290.599976  1293.400024  1289.199951  1293.400024   607.0
# 4 2019-04-12  1290.599976  1293.400024  1289.199951  1293.400024   607.0
#
#                                             headline  negative   neutral  \
# 0  One Dead In Microlight crash at Royal Birkdale...  0.028605  0.696439
# 1  Germany: Muslim Woman on trial for torturing S...  0.036242  0.753281
# 2  Jussie Smollett sued over Chicago police overt...  0.022014  0.918347
# 3  Authorities say deputys son behind fires at b...  0.051598  0.764348
# 4  White House proposed releasing immigrant detai...  0.025207  0.860364
#
#    positive  ...  season_Spring  season_Summer  season_Winter   Close_lag1  \
# 0  0.274956  ...           True          False          False  1288.599976
# 1  0.210477  ...           True          False          False  1288.599976
# 2  0.059639  ...           True          False          False  1288.599976
# 3  0.184054  ...           True          False          False  1288.599976
# 4  0.114429  ...           True          False          False  1288.599976
#
#    Close_lag3   Close_lag7  Close_lag14  Close_lag30  Close_roll_mean_7  \
# 0      1303.5  1289.900024  1321.900024  1296.400024        1295.371425
# 1      1303.5  1289.900024  1321.900024  1296.400024        1295.371425
# 2      1303.5  1289.900024  1321.900024  1296.400024        1295.371425
# 3      1303.5  1289.900024  1321.900024  1296.400024        1295.371425
# 4      1303.5  1289.900024  1321.900024  1296.400024        1295.371425
#
#    Close_roll_mean_30
# 0         1297.170015
# 1         1297.170015
# 2         1297.170015
# 3         1297.170015
# 4         1297.170015
#
# [5 rows x 36 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23396 entries, 0 to 23395
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                23396 non-null  datetime64[ns]
#  1   close               23396 non-null  float64
#  2   high                23396 non-null  float64
#  3   low                 23396 non-null  float64
#  4   open                23396 non-null  float64
#  5   volume              23396 non-null  float64
#  6   headline            23396 non-null  object
#  7   negative            23396 non-null  float64
#  8   neutral             23396 non-null  float64
#  9   positive            23396 non-null  float64
#  10  interest_rate       23396 non-null  float64
#  11  inflation           23396 non-null  float64
#  12  usd_index           23396 non-null  float64
#  13  year                23396 non-null  int64
#  14  month               23396 non-null  int64
#  15  day                 23396 non-null  int64
#  16  day_of_week         23396 non-null  int64
#  17  week_of_year        23396 non-null  int64
#  18  quarter             23396 non-null  int64
#  19  is_weekend          23396 non-null  int64
#  20  days_since_start    23396 non-null  int64
#  21  month_sin           23396 non-null  float64
#  22  month_cos           23396 non-null  float64
#  23  dayofweek_sin       23396 non-null  float64
#  24  dayofweek_cos       23396 non-null  float64
#  25  season_Autumn       23396 non-null  bool
#  26  season_Spring       23396 non-null  bool
#  27  season_Summer       23396 non-null  bool
#  28  season_Winter       23396 non-null  bool
#  29  Close_lag1          23396 non-null  float64
#  30  Close_lag3          23396 non-null  float64
#  31  Close_lag7          23396 non-null  float64
#  32  Close_lag14         23396 non-null  float64
#  33  Close_lag30         23396 non-null  float64
#  34  Close_roll_mean_7   23396 non-null  float64
#  35  Close_roll_mean_30  23396 non-null  float64
# dtypes: bool(4), datetime64[ns](1), float64(22), int64(8), object(1)
# memory usage: 5.8+ MB
# None
# date                  0
# close                 0
# high                  0
# low                   0
# open                  0
# volume                0
# headline              0
# negative              0
# neutral               0
# positive              0
# interest_rate         0
# inflation             0
# usd_index             0
# year                  0
# month                 0
# day                   0
# day_of_week           0
# week_of_year          0
# quarter               0
# is_weekend            0
# days_since_start      0
# month_sin             0
# month_cos             0
# dayofweek_sin         0
# dayofweek_cos         0
# season_Autumn         0
# season_Spring         0
# season_Summer         0
# season_Winter         0
# Close_lag1            0
# Close_lag3            0
# Close_lag7            0
# Close_lag14           0
# Close_lag30           0
# Close_roll_mean_7     0
# Close_roll_mean_30    0
# dtype: int64
#                                 date         close          high  \
# count                          23396  23396.000000  23396.000000
# mean   2023-03-07 00:17:39.873482496   2225.000587   2236.198676
# min              2019-04-12 00:00:00   1269.300049   1269.800049
# 25%              2021-08-20 00:00:00   1798.099976   1802.800049
# 50%              2023-11-17 00:00:00   2010.099976   2019.125031
# 75%              2024-09-20 00:00:00   2581.000000   2581.800049
# max              2025-10-10 00:00:00   4043.300049   4049.199951
# std                              NaN    631.153922    632.954755
#
#                 low          open         volume      negative       neutral  \
# count  23396.000000  23396.000000   23396.000000  23396.000000  23396.000000
# mean    2212.292966   2223.151399    3168.038247      0.115792      0.378664
# min     1266.000000   1266.400024       0.000000      0.000000      0.005701
# 25%     1789.599976   1794.900024      73.000000      0.024669      0.034438
# 50%     1999.750000   2014.500000     259.000000      0.041947      0.197526
# 75%     2566.000000   2572.666667     862.000000      0.097007      0.772941
# max     3987.199951   4011.199951  352500.000000      0.959394      1.000000
# std      623.774043    625.484510   17780.052512      0.193657      0.365671
#
#            positive  interest_rate  ...     month_cos  dayofweek_sin  \
# count  23396.000000   23396.000000  ...  2.339600e+04   23396.000000
# mean       0.505544       3.309104  ...  3.649210e-02      -0.196915
# min        0.000000       0.050000  ... -1.000000e+00      -0.974928
# 25%        0.149372       1.550000  ... -5.000000e-01      -0.433884
# 50%        0.549429       4.330000  ...  6.123234e-17      -0.433884
# 75%        0.850460       5.330000  ...  5.000000e-01       0.000000
# max        0.953901       5.330000  ...  1.000000e+00       0.974928
# std        0.340460       2.079914  ...  6.961668e-01       0.523355
#
#        dayofweek_cos    Close_lag1    Close_lag3    Close_lag7   Close_lag14  \
# count   23396.000000  23396.000000  23396.000000  23396.000000  23396.000000
# mean       -0.542199   2222.017146   2216.507819   2207.172041   2191.619026
# min        -0.900969   1269.300049   1269.300049   1269.300049   1269.300049
# 25%        -0.900969   1796.699951   1804.400024   1797.900024   1795.000000
# 50%        -0.900969   2014.100037   2014.300049   2010.900024   1994.199951
# 75%        -0.222521   2580.399902   2568.824951   2565.699951   2511.399902
# max         1.000000   4043.300049   3976.600098   3880.800049   3780.600098
# std         0.627194    624.134185    616.393765    605.780136    586.554838
#
#         Close_lag30  Close_roll_mean_7  Close_roll_mean_30
# count  23396.000000       23396.000000        23396.000000
# mean    2162.384566        2213.628281         2189.506239
# min     1269.300049        1272.471431         1279.669998
# 25%     1789.599976        1797.314279         1795.016675
# 50%     1987.199951        2007.900007         1995.153333
# 75%     2493.399902        2578.057129         2521.961641
# max     3643.300049        3946.400042         3778.201107
# std      559.945292         612.780254          584.502941
#
# [8 rows x 31 columns]
